# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
#possibilidade de especificar a versão

#headers = {'X-GitHub-Api-Version': '2022-11-28'}

# r = requests.get('https://api.github.com/events', headers=headers)

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code   #acessando apenas o status code
# Out:
# 200

# %%
r.url #acessando a url
# Out:
# 'https://api.github.com/events'

# %%
r.text #acessado o conteudo em formato de string
# Out:
# '[{"id":"38680164783","type":"DeleteEvent","actor":{"id":47565258,"login":"cvs-ops","display_login":"cvs-ops","gravatar_id":"","url":"https://api.github.com/users/cvs-ops","avatar_url":"https://avatars.githubusercontent.com/u/47565258?"},"repo":{"id":338050497,"name":"dvsa/cvs-svc-enquiry","url":"https://api.github.com/repos/dvsa/cvs-svc-enquiry"},"payload":{"ref":"feature/CVSB-17925","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2024-05-24T12:03:19Z","org":{"id":24296376,"login":"dvsa","gravatar_id":"","url":"https://api.github.com/orgs/dvsa","avatar_url":"https://avatars.githubusercontent.com/u/24296376?"}},{"id":"38680164814","type":"WatchEvent","actor":{"id":100728215,"login":"derwincabral","display_login":"derwincabral","gravatar_id":"","url":"https://api.github.com/users/derwincabral","avatar_url":"https://avatars.githubusercontent.com/u/100728215?"},"repo":{"id":640819432,"name":"smol-ai/GodMode","url":"https://api.github.com/repos/smol-ai/GodMode"},"pa
# ...

# %%
r.json() #acessando o conteudo em formato json
         #trazendo o conteudo da variavel que fez o request no formato json
# Out:
# [{'id': '38680164783',
#   'type': 'DeleteEvent',
#   'actor': {'id': 47565258,
#    'login': 'cvs-ops',
#    'display_login': 'cvs-ops',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cvs-ops',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47565258?'},
#   'repo': {'id': 338050497,
#    'name': 'dvsa/cvs-svc-enquiry',
#    'url': 'https://api.github.com/repos/dvsa/cvs-svc-enquiry'},
#   'payload': {'ref': 'feature/CVSB-17925',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-05-24T12:03:19Z',
#   'org': {'id': 24296376,
#    'login': 'dvsa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dvsa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24296376?'}},
#  {'id': '38680164814',
#   'type': 'WatchEvent',
#   'actor': {'id': 100728215,
#    'login': 'derwincabral',
#    'display_login': 'derwincabral',
#    'gravatar_id': '',
# ...

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
j = requests.get('https://api.github.com/users/jhoehashimoto')

# %%
nome = j.json()['name']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
username = 'amzn'     #username de quem vamos extrair os dados
url = f'{api_base_url}/users/{username}/repos'

# %%
response = requests.get(url,headers=headers)
response.status_code
# Out:
# 200

# %%
response.json() ##trazendo o conteúdo da requisição no formato json
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
headers = {
    'Authorization': 'Bearer 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',
    'X-GitHub-Api-Version': '2022-11-28'
}

# %% [markdown]
# ### Paginando os repositórios

# %%
repos_list = []

for page_num in range(1,6):
    try:
        url_page = f'{url}?page={page_num}' ##atribuindo o n da página a url
        response = requests.get(url_page, headers=headers)# parametrizando a url com o token e versão
        repos_list.append(response.json()) #adicionando o conteúdo da página na lista
    except:
        repos_list.append(None)

# %%
repos_list
#possui uma lista com sublistas e dicionários 
#a sublista é as páginas
#em suma traz o conteudo das 5 páginas
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(repos_list)   #contando quantidade de páginas
# Out:
# 5

# %%
len(repos_list[0])  #contando quantidade de repositórios presentes na primeira página
# Out:
# 30

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list[0][0]  #selecionando a primeira página e o primeiro repositório
# Out:
# {'id': 171339259,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#  'name': '.github',
#  'full_name': 'amzn/.github',
#  'private': False,
#  'owner': {'login': 'amzn',
#   'id': 8594673,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/amzn',
#   'html_url': 'https://github.com/amzn',
#   'followers_url': 'https://api.github.com/users/amzn/followers',
#   'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#   'organizations_url': 'https://api.github.com/users/amzn/orgs',
#   'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
repos_list[0][0]['name'] #trazendo o campo nome do primeiro repositório da primeira página
# Out:
# '.github'

# %%
repos_name = []

for page in repos_list:           #criando um for que irá percorrer a pag na lista de pag
    for repo in page:               #criando um for que ira percorrer os rep por pag
        repos_name.append(repo['name']) #adicionando o campo nome de cada pag e repositorio na lista de nomes de repositorios

# %%
repos_name[:10]  #listando apenas o nome de 10 repositórios
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs']

# %%
len(repos_name)
# Out:
# 150

# %%
type(repos_list)
# Out:
# list

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_list[1][1]['language']   #acessando o campo language do segundo repositorio da segunda página
# Out:
# 'PHP'

# %%
repos_language = []

for page in repos_list:           #criando um for que irá percorrer a pag na lista de pag
    for repo in page:               #criando um for que ira percorrer os rep por pag
        repos_language.append(repo['language']) #adicionando o campo language de cada pag e repositorio na lista de nomes de repositorios

# %%
len(repos_language)
# Out:
# 150

# %%
repos_language
# Out:
# [None,
#  None,
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  'TypeScript',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
# ...

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame() #criando o dataframe dados_amz

dados_amz['repository_name'] = repos_name #criando a coluna repository_name e add a lista repos_name
dados_amz['language'] = repos_language #criando a coluna language e add a lista repos_language

# %%
# ---OUTRA CRIAÇÃO ----
# dados_amz = {"Repository_Name" : repos_name, "Language" : repos_language}
# df = pd.DataFrame(dados_amz)

# %%
dados_amz
# Out:
#                  repository_name    language
# 0                        .github        None
# 1        ads-advanced-tools-docs        None
# 2    ads-pao-amznjs-gtm-template      Smarty
# 3                     alexa-coho  JavaScript
# 4            alexa-skills-kit-js        None
# ..                           ...         ...
# 145           workspace-resolver  JavaScript
# 146                       ws-vae      Python
# 147                         xfer      Python
# 148           zeek-plugin-bacnet        Zeek
# 149             zeek-plugin-enip        Zeek
#
# [150 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame

# %%
dados_amz.to_csv('amazon.csv')   #salvando o dataframe em csv

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url

        #acessando a rota de repositórios
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name':'pipeline-etlAPI',
    'description':'This is your first repo!',
    'private': False
}

response = requests.post(url, json=data,headers=headers)
response.status_code
# Out:
# 422

# %%
response.content
# Out:
# b'{"message":"Repository creation failed.","errors":[{"resource":"Repository","code":"custom","field":"name","message":"name already exists on this account"}],"documentation_url":"https://docs.github.com/rest/repos/repos#create-a-repository-for-the-authenticated-user"}'

# %% [markdown]
# ### Formato do arquivo

# %%
import base64

# %%
with open('amazon.csv', 'rb') as file: #transformando o arquivo para base 64
    file_content = file.read()

encoded_content = base64.b64encode(file_content)  #salvando o arquivo na base 64 através da variável content

# %% [markdown]
# ### Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'jhoehashimoto'
repo = 'pipeline-etlAPI'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/jhoehashimoto/pipeline-etlAPI/contents/amazon.csv'

# %%
data = {
    'message' : 'Adicionando o arquivo codificado',
    'content' : encoded_content.decode('utf-8')   ##transformando o arquivo codificado em texto utf8
}


response = request.put(url, json=data, headers=headers)
response.status_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 7
#       1 data = {
#       2     'message' : 'Adicionando o arquivo codificado',
#       3     'content' : encoded_content.decode('utf-8')   ##transformando o arquivo codificado em texto utf8
#       4 }
# ----> 7 response = request.put(url, json=data, headers=headers)
#       8 response.status_code
#
# NameError: name 'request' is not defined
